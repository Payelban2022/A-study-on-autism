# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
toddlers1_df = pd.read_csv('Study on toddlers.csv')

# %%
toddlers1_df.head()
# Out:
#    Unnamed: 0  Case_No  A1  A2  A3  A4  A5  A6  A7  A8  ...  Age_Mons  \
# 0           1        2   1   1   0   0   0   1   1   0  ...        36
# 1           2        3   1   0   0   0   0   0   1   1  ...        36
# 2           3        4   1   1   1   1   1   1   1   1  ...        24
# 3           4        5   1   1   0   1   1   1   1   1  ...        20
# 4           5        6   1   1   0   0   1   1   1   1  ...        21
#
#    Qchat-10-Score  Gender       Ethnicity Jaundice Family_mem_with_ASD  \
# 0               4       m  White European      yes                  no
# 1               4       m  middle eastern      yes                  no
# 2              10       m        Hispanic       no                  no
# 3               9       f  White European       no                 yes
# 4               8       m           black       no                  no
#
#   Who completed the test Class/ASD Traits  Probable_case age-group
# ...

# %%
adults_df = pd.read_csv('Study on adults.csv')

# %%
adults_df.head()
# Out:
#    Unnamed: 0  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  \
# 0           0         1         1         1         1         0         0
# 1           1         1         1         0         1         0         0
# 2           2         1         1         0         1         1         0
# 3           3         1         1         0         1         0         0
# 4           5         1         1         1         1         1         0
#
#    A7_Score  A8_Score  A9_Score  A10_Score Gender       Ethnicity Jaundice  \
# 0         1         1         0          0      f  White-European       no
# 1         0         1         0          1      m          Latino       no
# 2         1         1         1          1      m          Latino      yes
# 3         1         1         0          1      f  White-European       no
# 4         1         1         1          1      m          Others      yes
#
# ...

# %%
adults_df['Class/ASD Traits'] = adults_df['Class/ASD Traits'].str.lower()

# %%
toddlers1_df['Class/ASD Traits'] = adults_df['Class/ASD Traits'].str.lower()

# %%
adults_df.head()
# Out:
#    Unnamed: 0  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  \
# 0           0         1         1         1         1         0         0
# 1           1         1         1         0         1         0         0
# 2           2         1         1         0         1         1         0
# 3           3         1         1         0         1         0         0
# 4           5         1         1         1         1         1         0
#
#    A7_Score  A8_Score  A9_Score  A10_Score Gender       Ethnicity Jaundice  \
# 0         1         1         0          0      f  White-European       no
# 1         0         1         0          1      m          Latino       no
# 2         1         1         1          1      m          Latino      yes
# 3         1         1         0          1      f  White-European       no
# 4         1         1         1          1      m          Others      yes
#
# ...

# %%
adults_df['Who completed the test'].unique()
# Out:
# array(['Self', 'Parent', 'Health care professional', 'Relative', 'Others'],
#       dtype=object)

# %%
toddlers1_df['Who completed the test'].unique()
# Out:
# array(['family member', 'Health Care Professional', 'Others', 'Self',
#        'Health care professional'], dtype=object)

# %%
toddlers1_df['Who completed the test'] = toddlers1_df['Who completed the test'].replace('Health Care Professional', 'Health care professional')

# %%
toddlers1_df['Who completed the test'].unique()
# Out:
# array(['family member', 'Health care professional', 'Others', 'Self'],
#       dtype=object)

# %%
adults_df['Who completed the test'] = adults_df['Who completed the test'].replace('Parent', 'family member')

# %%
adults_df['Who completed the test'] = adults_df['Who completed the test'].replace('Relative', 'family member')

# %%
adults_df['Who completed the test'].unique()
# Out:
# array(['Self', 'family member', 'Health care professional', 'Others'],
#       dtype=object)

# %%
adults_df['Family_mem_with_ASD'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
toddlers1_df['Family_mem_with_ASD'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
adults_df.drop(adults_df.iloc[:,1:11], inplace=True, axis=1)

# %%
adults_df
# Out:
#      Unnamed: 0 Gender       Ethnicity Jaundice Family_mem_with_ASD  \
# 0             0      f  White-European       no                  no
# 1             1      m          Latino       no                 yes
# 2             2      m          Latino      yes                 yes
# 3             3      f  White-European       no                 yes
# 4             5      m          Others      yes                  no
# ..          ...    ...             ...      ...                 ...
# 468         697      f        Pasifika       no                  no
# 469         698      f  White-European       no                  no
# 470         700      f          Others       no                  no
# 471         701      m     South Asian       no                  no
# 472         702      f  White-European       no                  no
#
#     Who completed the test Class/ASD Traits  Qchat-10-Score Probable_case  \
# 0                     Self               no               6           yes
# ...

# %%
toddlers1_df.drop(toddlers1_df.iloc[:,1:12], inplace=True, axis=1)

# %%
toddlers1_df
# Out:
#      Unnamed: 0  Age_Mons  Qchat-10-Score Gender       Ethnicity Jaundice  \
# 0             1        36               4      m  White European      yes
# 1             2        36               4      m  middle eastern      yes
# 2             3        24              10      m        Hispanic       no
# 3             4        20               9      f  White European       no
# 4             5        21               8      m           black       no
# ..          ...       ...             ...    ...             ...      ...
# 723        1046        24               7      f  middle eastern       no
# 724        1047        30               5      f  White European       no
# 725        1050        12               5      m           black      yes
# 726        1051        18               9      m  middle eastern      yes
# 727        1053        24               6      m           asian      yes
#
#     Family_mem_with_ASD Who completed the test Class/ASD Traits   \
# ...

# %%
toddlers1_df.drop('Age_Mons', axis = 1, inplace=True)

# %%
toddlers1_df
# Out:
#      Unnamed: 0  Qchat-10-Score Gender       Ethnicity Jaundice  \
# 0             1               4      m  White European      yes
# 1             2               4      m  middle eastern      yes
# 2             3              10      m        Hispanic       no
# 3             4               9      f  White European       no
# 4             5               8      m           black       no
# ..          ...             ...    ...             ...      ...
# 723        1046               7      f  middle eastern       no
# 724        1047               5      f  White European       no
# 725        1050               5      m           black      yes
# 726        1051               9      m  middle eastern      yes
# 727        1053               6      m           asian      yes
#
#     Family_mem_with_ASD Who completed the test Class/ASD Traits   \
# 0                    no          family member               Yes
# ...

# %%
toddlers1_df.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
adults_df.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
toddlers1_df.head()
# Out:
#    Qchat-10-Score Gender       Ethnicity Jaundice Family_mem_with_ASD  \
# 0               4      m  White European      yes                  no
# 1               4      m  middle eastern      yes                  no
# 2              10      m        Hispanic       no                  no
# 3               9      f  White European       no                 yes
# 4               8      m           black       no                  no
#
#   Who completed the test Class/ASD Traits  Probable_case age-group
# 0          family member               Yes           yes  Toddlers
# 1          family member               Yes           yes  Toddlers
# 2          family member               Yes           yes  Toddlers
# 3          family member               Yes           yes  Toddlers
# 4          family member               Yes           yes  Toddlers

# %%
toddlers1_df.rename(columns={'Class/ASD Traits':'ASD_traits'},inplace = True)

# %%
toddlers1_df.head()
# Out:
#    Qchat-10-Score Gender       Ethnicity Jaundice Family_mem_with_ASD  \
# 0               4      m  White European      yes                  no
# 1               4      m  middle eastern      yes                  no
# 2              10      m        Hispanic       no                  no
# 3               9      f  White European       no                 yes
# 4               8      m           black       no                  no
#
#   Who completed the test Class/ASD Traits  Probable_case age-group
# 0          family member               Yes           yes  Toddlers
# 1          family member               Yes           yes  Toddlers
# 2          family member               Yes           yes  Toddlers
# 3          family member               Yes           yes  Toddlers
# 4          family member               Yes           yes  Toddlers

# %%
adults_df.head()
# Out:
#   Gender       Ethnicity Jaundice Family_mem_with_ASD Who completed the test  \
# 0      f  White-European       no                  no                   Self
# 1      m          Latino       no                 yes                   Self
# 2      m          Latino      yes                 yes          family member
# 3      f  White-European       no                 yes                   Self
# 4      m          Others      yes                  no                   Self
#
#   Class/ASD Traits  Qchat-10-Score Probable_case      age-group
# 0               no               6           yes  Adults(Young)
# 1               no               5           yes          Youth
# 2              yes               8           yes  Adults(Young)
# 3               no               6           yes  Adults(Young)
# 4              yes               9           yes    Adults(Mid)

# %%
toddlers1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Qchat-10-Score          728 non-null    int64
#  1   Gender                  728 non-null    object
#  2   Ethnicity               728 non-null    object
#  3   Jaundice                728 non-null    object
#  4   Family_mem_with_ASD     728 non-null    object
#  5   Who completed the test  728 non-null    object
#  6   Class/ASD Traits        728 non-null    object
#  7   Probable_case           728 non-null    object
#  8   age-group               728 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 51.3+ KB

# %%
adults_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473 entries, 0 to 472
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  473 non-null    object
#  1   Ethnicity               473 non-null    object
#  2   Jaundice                473 non-null    object
#  3   Family_mem_with_ASD     473 non-null    object
#  4   Who completed the test  473 non-null    object
#  5   Class/ASD Traits        473 non-null    object
#  6   Qchat-10-Score          473 non-null    int64
#  7   Probable_case           473 non-null    object
#  8   age-group               473 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 33.4+ KB

# %%
frames = [toddlers1_df, adults_df]
df2 = pd.concat(frames)

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#       Qchat-10-Score Gender       Ethnicity Jaundice Family_mem_with_ASD  \
# 0                  4      m  White European      yes                  no
# 1                  4      m  middle eastern      yes                  no
# 2                 10      m        Hispanic       no                  no
# 3                  9      f  White European       no                 yes
# 4                  8      m           black       no                  no
# ...              ...    ...             ...      ...                 ...
# 1196              10      f        Pasifika       no                  no
# 1197               7      f  White-European       no                  no
# 1198               7      f          Others       no                  no
# 1199               6      m     South Asian       no                  no
# 1200               8      f  White-European       no                  no
#
#      Who completed the test Class/ASD Traits  Probable_case      age-group  \
# ...

# %%
toddlers1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Qchat-10-Score          728 non-null    int64
#  1   Gender                  728 non-null    object
#  2   Ethnicity               728 non-null    object
#  3   Jaundice                728 non-null    object
#  4   Family_mem_with_ASD     728 non-null    object
#  5   Who completed the test  728 non-null    object
#  6   Class/ASD Traits        728 non-null    object
#  7   Probable_case           728 non-null    object
#  8   age-group               728 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 51.3+ KB
